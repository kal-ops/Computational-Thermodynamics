# %% [markdown]
# <a href="https://colab.research.google.com/github/kal-ops/Computational-Thermodynamics/blob/main/Comp_thermo_3D_plot_critical_temperatures_800_C_start_temp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3D plot of A3 Transformation Temperatures

# %%
#importing the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

# %%
#preparing the Data
df = pd.read_csv("Plot points_ A3 Transformation temperatures in Celsius  - Sheet1.csv")
#Dropping all NaN values in the Relaxed condition: Temperature column
df = df.dropna(subset = ["A3"])

# %%
df
# Out:
#               A3  Mass percent Fe  Mass percent Si  Mass percent Al  \
# 0      836.40579             99.8              0.0              0.0
# 1      827.63752             99.5              0.0              0.0
# 2      819.13497             99.2              0.0              0.0
# 3      810.88512             98.9              0.0              0.0
# 4      802.87610             98.6              0.0              0.0
# ...          ...              ...              ...              ...
# 1242   949.27765             93.2              3.0              0.6
# 1250  1106.13658             93.8              3.0              0.9
# 1251  1065.75606             93.5              3.0              0.9
# 1252  1034.73121             93.2              3.0              0.9
# 1253  1008.42805             92.9              3.0              0.9
#
#       Mass percent Mn  Temperature [°C]
# 0                 0.0               800
# 1                 0.3               800
# 2                 0.6               800
# 3                 0.9               800
# 4                 1.2               800
# ...               ...               ...
# 1242              3.0               800
# 1250              2.1               800
# 1251              2.4               800
# 1252              2.7               800
# 1253              3.0               800
#
# [677 rows x 6 columns]

# %%
df.to_csv("A3 temps cleaned up.csv", index=False)

# %%
df.describe()
# Out:
#                 A3  Mass percent Fe  Mass percent Si  Mass percent Al  \
# count   677.000000       677.000000       677.000000       677.000000
# mean    940.897629        96.134417         1.240768         0.775480
# std      85.282514         1.413056         0.904979         0.597818
# min     759.333980        92.900000         0.000000         0.000000
# 25%     873.904180        95.000000         0.600000         0.300000
# 50%     936.217680        96.200000         1.200000         0.600000
# 75%    1004.540210        97.100000         2.100000         1.200000
# max    1126.804640        99.800000         3.000000         2.400000
#
#        Mass percent Mn  Temperature [°C]
# count       677.000000             677.0
# mean          1.649335             800.0
# std           0.935203               0.0
# min           0.000000             800.0
# 25%           0.900000             800.0
# 50%           1.800000             800.0
# 75%           2.400000             800.0
# max           3.000000             800.0

# %%
#Now let us assign each column into an axis and make an array
#Let us typecast the df column into a list to remove the index and then put it into the list
x_data = [list(df['Mass percent Al'])]
y_data = [list(df['Mass percent Mn'])]
z_data = [list(df['Mass percent Si'])]
#an array of temperatures that will be used to define the color later
colors = [list(df['A3'])]

# %%
#let us use colormap to bring the varying color in
from matplotlib.colors import ListedColormap

#creating a 3D axis
axis = plt.axes(projection = "3d")

#shifting the view
axis.view_init(elev=30, azim=-120)

#creating the plot and mapping color to temperature
scatter = axis.scatter(x_data, y_data, z_data, c = colors, cmap = 'Reds', alpha = 0.8)
plt.colorbar(scatter, ax=axis)
axis.set_xlabel("Mass percent Al")
axis.set_ylabel("Mass percent Mn")
axis.set_zlabel("Mass percent Si")
plt.show()
